# %%
print('Hello World')
# Out:
# Hello World

# %%
import pandas as pd

df = pd.read_csv('/kaggle/input/destinations/Destination.csv')

# %%
df
# Out:
#       id     Destination  Feedback  Avg Rating  All in Hotels   Most Popular
# 0    1.0     New Zealand       9.0         4.0            5.0         Rotura
# 1    2.0      North Pole       8.0         4.0            6.0       Svalbard
# 2    3.0    Turkmenistan       7.0         3.0            9.0        Derweze
# 3    4.0          Russia       8.0         5.0           17.0  Yekaterinburg
# 4    5.0         Austria       9.0         4.0           12.0    Hinterbruhl
# 5    6.0           China       8.0         3.0          198.0       Xinjiang
# 6    7.0           Italy       9.0         5.0           76.0         Puglia
# 7    8.0          France       6.0         3.0           24.0         Nantes
# 8    9.0           India       8.0         3.0           45.0         Ladakh
# 9   10.0       Indonesia       9.0         4.0           80.0           Aceh
# 10  11.0           Japan      10.0         5.0           90.0          Beppu
# ...

# %%
df
# Out:
#       id     Destination  Feedback  Avg Rating  All in Hotels   Most Popular
# 0    1.0     New Zealand       9.0         4.0            5.0         Rotura
# 1    2.0      North Pole       8.0         4.0            6.0       Svalbard
# 2    3.0    Turkmenistan       7.0         3.0            9.0        Derweze
# 3    4.0          Russia       8.0         5.0           17.0  Yekaterinburg
# 4    5.0         Austria       9.0         4.0           12.0    Hinterbruhl
# 5    6.0           China       8.0         3.0          198.0       Xinjiang
# 6    7.0           Italy       9.0         5.0           76.0         Puglia
# 7    8.0          France       6.0         3.0           24.0         Nantes
# 8    9.0           India       8.0         3.0           45.0         Ladakh
# 9   10.0       Indonesia       9.0         4.0           80.0           Aceh
# 10  11.0           Japan      10.0         5.0           90.0          Beppu
# ...

# %%
df.head(10)
# Out:
#      id   Destination  Feedback  Avg Rating  All in Hotels   Most Popular
# 0   1.0   New Zealand       9.0         4.0            5.0         Rotura
# 1   2.0    North Pole       8.0         4.0            6.0       Svalbard
# 2   3.0  Turkmenistan       7.0         3.0            9.0        Derweze
# 3   4.0        Russia       8.0         5.0           17.0  Yekaterinburg
# 4   5.0       Austria       9.0         4.0           12.0    Hinterbruhl
# 5   6.0         China       8.0         3.0          198.0       Xinjiang
# 6   7.0         Italy       9.0         5.0           76.0         Puglia
# 7   8.0        France       6.0         3.0           24.0         Nantes
# 8   9.0         India       8.0         3.0           45.0         Ladakh
# 9  10.0     Indonesia       9.0         4.0           80.0           Aceh

# %%
df.tail()
# Out:
#       id     Destination  Feedback  Avg Rating  All in Hotels Most Popular
# 12  13.0       Palestine       9.0         3.0            5.0    Jerusalem
# 13  14.0            Oman       7.0         5.0            2.0        Bahla
# 14  15.0  United Kingdom       7.0         4.0           20.0       London
# 15   NaN             NaN       NaN         NaN            NaN          NaN
# 16   NaN             NaN       NaN         NaN            NaN          NaN

# %%
df.tail(10)
# Out:
#       id     Destination  Feedback  Avg Rating  All in Hotels Most Popular
# 7    8.0          France       6.0         3.0           24.0       Nantes
# 8    9.0           India       8.0         3.0           45.0       Ladakh
# 9   10.0       Indonesia       9.0         4.0           80.0         Aceh
# 10  11.0           Japan      10.0         5.0           90.0        Beppu
# 11  12.0          Turkey       9.0         4.0           54.0      Faralya
# 12  13.0       Palestine       9.0         3.0            5.0    Jerusalem
# 13  14.0            Oman       7.0         5.0            2.0        Bahla
# 14  15.0  United Kingdom       7.0         4.0           20.0       London
# 15   NaN             NaN       NaN         NaN            NaN          NaN
# 16   NaN             NaN       NaN         NaN            NaN          NaN

# %% [markdown]
# # Pandas two main data structure

# %%
df.Destination
# Out:
# 0        New Zealand
# 1         North Pole
# 2       Turkmenistan
# 3             Russia
# 4            Austria
# 5              China
# 6              Italy
# 7             France
# 8              India
# 9          Indonesia
# 10             Japan
# 11            Turkey
# 12         Palestine
# 13              Oman
# 14    United Kingdom
# 15               NaN
# 16               NaN
# Name: Destination, dtype: object

# %%
df.columns
# Out:
# Index(['id', 'Destination', 'Feedback', 'Avg Rating', 'All in Hotels',
#        'Most Popular'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=17, step=1)

# %%
df.shape
# Out:
# (17, 6)

# %%
df.dtypes
# Out:
# id               float64
# Destination       object
# Feedback         float64
# Avg Rating       float64
# All in Hotels    float64
# Most Popular      object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             15 non-null     float64
#  1   Destination    15 non-null     object
#  2   Feedback       15 non-null     float64
#  3   Avg Rating     15 non-null     float64
#  4   All in Hotels  15 non-null     float64
#  5   Most Popular   15 non-null     object
# dtypes: float64(4), object(2)
# memory usage: 944.0+ bytes

# %%
df.Feedback
# Out:
# 0      9.0
# 1      8.0
# 2      7.0
# 3      8.0
# 4      9.0
# 5      8.0
# 6      9.0
# 7      6.0
# 8      8.0
# 9      9.0
# 10    10.0
# 11     9.0
# 12     9.0
# 13     7.0
# 14     7.0
# 15     NaN
# 16     NaN
# Name: Feedback, dtype: float64

# %%
df[['Destination', 'id']].head()
# Out:
#     Destination   id
# 0   New Zealand  1.0
# 1    North Pole  2.0
# 2  Turkmenistan  3.0
# 3        Russia  4.0
# 4       Austria  5.0

# %%
df[4:10]
# Out:
#      id Destination  Feedback  Avg Rating  All in Hotels Most Popular
# 4   5.0     Austria       9.0         4.0           12.0  Hinterbruhl
# 5   6.0       China       8.0         3.0          198.0     Xinjiang
# 6   7.0       Italy       9.0         5.0           76.0       Puglia
# 7   8.0      France       6.0         3.0           24.0       Nantes
# 8   9.0       India       8.0         3.0           45.0       Ladakh
# 9  10.0   Indonesia       9.0         4.0           80.0         Aceh

# %%
df.iloc[1:4, [1, 2, 3]]
# Out:
#     Destination  Feedback  Avg Rating
# 1    North Pole       8.0         4.0
# 2  Turkmenistan       7.0         3.0
# 3        Russia       8.0         5.0

# %%
df.loc[1:11, 'Avg Rating']
# Out:
# 1     4.0
# 2     3.0
# 3     5.0
# 4     4.0
# 5     3.0
# 6     5.0
# 7     3.0
# 8     3.0
# 9     4.0
# 10    5.0
# 11    4.0
# Name: Avg Rating, dtype: float64

# %%
df.rename(columns = {'Avg Hotel' : 'Avg_Hotel' })
# Out:
#       id     Destination  Feedback  Avg Rating  All in Hotels   Most Popular
# 0    1.0     New Zealand       9.0         4.0            5.0         Rotura
# 1    2.0      North Pole       8.0         4.0            6.0       Svalbard
# 2    3.0    Turkmenistan       7.0         3.0            9.0        Derweze
# 3    4.0          Russia       8.0         5.0           17.0  Yekaterinburg
# 4    5.0         Austria       9.0         4.0           12.0    Hinterbruhl
# 5    6.0           China       8.0         3.0          198.0       Xinjiang
# 6    7.0           Italy       9.0         5.0           76.0         Puglia
# 7    8.0          France       6.0         3.0           24.0         Nantes
# 8    9.0           India       8.0         3.0           45.0         Ladakh
# 9   10.0       Indonesia       9.0         4.0           80.0           Aceh
# 10  11.0           Japan      10.0         5.0           90.0          Beppu
# ...

# %%
df.rename(columns = {'Most Popular' : 'Best Hotel' })
# Out:
#       id     Destination  Feedback  Avg Rating  All in Hotels     Best Hotel
# 0    1.0     New Zealand       9.0         4.0            5.0         Rotura
# 1    2.0      North Pole       8.0         4.0            6.0       Svalbard
# 2    3.0    Turkmenistan       7.0         3.0            9.0        Derweze
# 3    4.0          Russia       8.0         5.0           17.0  Yekaterinburg
# 4    5.0         Austria       9.0         4.0           12.0    Hinterbruhl
# 5    6.0           China       8.0         3.0          198.0       Xinjiang
# 6    7.0           Italy       9.0         5.0           76.0         Puglia
# 7    8.0          France       6.0         3.0           24.0         Nantes
# 8    9.0           India       8.0         3.0           45.0         Ladakh
# 9   10.0       Indonesia       9.0         4.0           80.0           Aceh
# 10  11.0           Japan      10.0         5.0           90.0          Beppu
# ...

# %% [markdown]
# # Statistical ananlysis of dataframe

# %%
df.describe()
# Out:
#               id   Feedback  Avg Rating  All in Hotels
# count  15.000000  15.000000   15.000000      15.000000
# mean    8.000000   8.200000    3.933333      42.866667
# std     4.472136   1.082326    0.798809      52.398019
# min     1.000000   6.000000    3.000000       2.000000
# 25%     4.500000   7.500000    3.000000       7.500000
# 50%     8.000000   8.000000    4.000000      20.000000
# 75%    11.500000   9.000000    4.500000      65.000000
# max    15.000000  10.000000    5.000000     198.000000

# %%
df.sort_values('All in Hotels').head()
# Out:
#       id   Destination  Feedback  Avg Rating  All in Hotels Most Popular
# 13  14.0          Oman       7.0         5.0            2.0        Bahla
# 0    1.0   New Zealand       9.0         4.0            5.0       Rotura
# 12  13.0     Palestine       9.0         3.0            5.0    Jerusalem
# 1    2.0    North Pole       8.0         4.0            6.0     Svalbard
# 2    3.0  Turkmenistan       7.0         3.0            9.0      Derweze

# %%
df.sort_values('All in Hotels', ascending = False).head()
# Out:
#       id Destination  Feedback  Avg Rating  All in Hotels Most Popular
# 5    6.0       China       8.0         3.0          198.0     Xinjiang
# 10  11.0       Japan      10.0         5.0           90.0        Beppu
# 9   10.0   Indonesia       9.0         4.0           80.0         Aceh
# 6    7.0       Italy       9.0         5.0           76.0       Puglia
# 11  12.0      Turkey       9.0         4.0           54.0      Faralya

# %%
df.sort_values(['Avg Rating', 'Destination'], ascending = [True, False])
# Out:
#       id     Destination  Feedback  Avg Rating  All in Hotels   Most Popular
# 2    3.0    Turkmenistan       7.0         3.0            9.0        Derweze
# 12  13.0       Palestine       9.0         3.0            5.0      Jerusalem
# 8    9.0           India       8.0         3.0           45.0         Ladakh
# 7    8.0          France       6.0         3.0           24.0         Nantes
# 5    6.0           China       8.0         3.0          198.0       Xinjiang
# 14  15.0  United Kingdom       7.0         4.0           20.0         London
# 11  12.0          Turkey       9.0         4.0           54.0        Faralya
# 1    2.0      North Pole       8.0         4.0            6.0       Svalbard
# 0    1.0     New Zealand       9.0         4.0            5.0         Rotura
# 9   10.0       Indonesia       9.0         4.0           80.0           Aceh
# 4    5.0         Austria       9.0         4.0           12.0    Hinterbruhl
# ...

# %%
df['All in Hotels'].max()
# Out:
# 198.0

# %%
df['Feedback'].max()
# Out:
# 10.0

# %%
df_filter = df[df['Avg Rating'] >3 ]
destinations = df_filter['Destination']

# %%
destinations
# Out:
# 0        New Zealand
# 1         North Pole
# 3             Russia
# 4            Austria
# 6              Italy
# 9          Indonesia
# 10             Japan
# 11            Turkey
# 13              Oman
# 14    United Kingdom
# Name: Destination, dtype: object
